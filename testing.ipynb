# %%
from age_groups_func import age_groups

# %%
help(age_groups)
# Out:
# Help on function age_groups in module age_groups_func:
#
# age_groups(ages)
#     Create age bands from age
#
#     This function creates age bands based on the input of ages and the breaks.
#     The output is a list of corresponding age bands for the inputs.
#
#     Parameters
#     ----------
#     ages : int
#         A list of integers or a single integer used as age to be converted to a corresponding age band.
#     breaks : int
#         A list of integers to be used to create the breaks for the age bands.
#
#     Returns
#     -------
#     str
#         The corresponding age bands of the inputted ages.
#
#     Examples
#     --------
#     >>>

# %% [markdown]
# # Doctest

# %%
import doctest

# %%
age_groups(1)
# Out:
# array(['0-9'], dtype='<U5')

# %%
def testing():
    """
    >>> print(age_groups(1))
    ['0-9']
    """

def testing1():
    """
    >>> print(age_groups(10))
    ['10-19']

    """

def testing2():
    """
    >>> print(age_groups(55))
    ['50-59']

    """

def testing3():
    """
    >>> print(age_groups([1, 10, 55]))
    ['0-9' '10-19' '50-59']

    """

def testing4():
    """
    >>> print(age_groups([5, 15, 25, 35, 45, 55, 65, 75, 85]))
    ['0-9' '10-19' '20-29' '30-39' '40-49' '50-59' '60-69' '70-79' '80-89']

    """

# %%
doctest.testmod(verbose=True)
# Out:
# Trying:
#     print(age_groups(1))
# Expecting:
#     ['0-9']
# ok
# Trying:
#     print(age_groups(10))
# Expecting:
#     ['10-19']
# ok
# Trying:
#     print(age_groups(55))
# Expecting:
#     ['50-59']
# ok
# Trying:
#     print(age_groups([1, 10, 55]))
# Expecting:
#     ['0-9' '10-19' '50-59']
# ok
# Trying:
#     print(age_groups([5, 15, 25, 35, 45, 55, 65, 75, 85]))
# Expecting:
#     ['0-9' '10-19' '20-29' '30-39' '40-49' '50-59' '60-69' '70-79' '80-89']
# ok
# 23 items had no tests:
#     __main__
#     __main__.DeepnoteChart
#     __main__.DeepnoteChart.__init__
#     __main__.DeepnoteChart._repr_mimebundle_
#     __main__._deepnote_add_formatters
#     __main__._deepnote_browse_df
#     __main__._deepnote_convert_objects_to_string
#     __main__._deepnote_convert_timedelta_columns_to_seconds
#     __main__._deepnote_escape_jinja_template
#     __main__._deepnote_execute_sql
#     __main__._deepnote_execute_sql_on_engine
#     __main__._deepnote_export_df
#     __main__._deepnote_get_used_fields_from_vega_lite_spec
#     __main__._deepnote_get_var_list
#     __main__._deepnote_persist_notebook_session
#     __main__._deepnote_prepare_connection_for_duckdb
#     __main__._deepnote_remove_system_modules_from_globals
#     __main__._deepnote_render_template
#     __main__._deepnote_restore_notebook_session
#     __main__._deepnote_sanitize_dataframe
#     __main__._deepnote_set_integration_env
#     __main__._deepnote_verify_chart
#     __main__._set_notebook_path
# 5 items passed all tests:
#    1 tests in __main__.testing
#    1 tests in __main__.testing1
#    1 tests in __main__.testing2
#    1 tests in __main__.testing3
#    1 tests in __main__.testing4
# 5 tests in 28 items.
# 5 passed and 0 failed.
# Test passed.
# TestResults(failed=0, attempted=5)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=273609b4-4e9d-4f33-aab5-a39e5df1d421' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
